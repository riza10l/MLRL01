# %%
ini adalah python with steroid on it

# %%
x = 10
y = 5

# %%
x + x + z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x + x + z
#
# NameError: name 'z' is not defined
